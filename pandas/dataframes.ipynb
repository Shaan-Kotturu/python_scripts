# %%
import pandas as pd

#employee_id = {
#    "ID": ["101","102","103","104"],
#    "Name" : ["Shaan","Ravi","Kiran","Varun"],
#    "City" : ["Bangalore","Hyderabad","Pune","Surat"]
#}
#table = pd.DataFrame(employee_id)
#print(table)

#read html and convert copy table to excel
df = pd.read_html("onhold.html")
df1 = df[2]
df1.to_excel("onhold_table_2.xlsx", index=False)
